# %% [markdown]
# # Convolutional Neural Network

# %% [markdown]
# ### Importing the libraries

# %%
import tensorflow as tf
from keras.preprocessing.image import ImageDataGenerator

# %%
tf.__version__
# Out:
# '2.10.0'

# %% [markdown]
# ## Part 1 - Data Preprocessing

# %% [markdown]
# ### Preprocessing the Training set

# %%
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)
training_set = train_datagen.flow_from_directory('dataset/training_set',
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'binary')
# Out:
# Found 8000 images belonging to 2 classes.

# %% [markdown]
# ### Preprocessing the Test set

# %%
test_datagen = ImageDataGenerator(rescale = 1./255)
test_set = test_datagen.flow_from_directory('dataset/test_set',
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %% [markdown]
# ## Part 2 - Building the CNN

# %% [markdown]
# ### Initialising the CNN

# %%
cnn = tf.keras.models.Sequential()

# %% [markdown]
# ### Step 1 - Convolution

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu', input_shape=[64, 64, 3]))

# %% [markdown]
# ### Step 2 - Pooling

# %%
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Adding a second convolutional layer

# %%
cnn.add(tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation='relu'))
cnn.add(tf.keras.layers.MaxPool2D(pool_size=2, strides=2))

# %% [markdown]
# ### Step 3 - Flattening

# %%
cnn.add(tf.keras.layers.Flatten())

# %% [markdown]
# ### Step 4 - Full Connection

# %%
cnn.add(tf.keras.layers.Dense(units=128, activation='relu'))

# %% [markdown]
# ### Step 5 - Output Layer

# %%
cnn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## Part 3 - Training the CNN

# %% [markdown]
# ### Compiling the CNN

# %%
cnn.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Training the CNN on the Training set and evaluating it on the Test set

# %%
cnn.fit(x = training_set, validation_data = test_set, epochs = 25)
# Out:
# Epoch 1/25
# 250/250 [==============================] - 69s 275ms/step - loss: 0.6728 - accuracy: 0.5753 - val_loss: 0.6548 - val_accuracy: 0.6260
# Epoch 2/25
# 250/250 [==============================] - 60s 239ms/step - loss: 0.5976 - accuracy: 0.6809 - val_loss: 0.5933 - val_accuracy: 0.7000
# Epoch 3/25
# 250/250 [==============================] - 67s 268ms/step - loss: 0.5631 - accuracy: 0.7063 - val_loss: 0.6116 - val_accuracy: 0.6705
# Epoch 4/25
# 250/250 [==============================] - 58s 232ms/step - loss: 0.5245 - accuracy: 0.7399 - val_loss: 0.5433 - val_accuracy: 0.7440
# Epoch 5/25
# 250/250 [==============================] - 54s 211ms/step - loss: 0.5153 - accuracy: 0.7430 - val_loss: 0.5119 - val_accuracy: 0.7490
# Epoch 6/25
# 250/250 [==============================] - 54s 215ms/step - loss: 0.4864 - accuracy: 0.7665 - val_loss: 0.5284 - val_accuracy: 0.7315
# Epoch 7/25
# 250/250 [==============================] - 53s 211ms/step - loss: 0.4725 - accuracy: 0.7756 - val_loss: 0.5035 - val_accuracy: 0.7590
# Epoch 8/25
# 250/250 [==============================] - 63s 253ms/step - loss: 0.4569 - accuracy: 0.7803 - val_loss: 0.4851 - val_accuracy: 0.7715
# Epoch 9/25
# 250/250 [==============================] - 41s 164ms/step - loss: 0.4401 - accuracy: 0.7985 - val_loss: 0.4870 - val_accuracy: 0.7670
# Epoch 10/25
# 250/250 [==============================] - 39s 155ms/step - loss: 0.4399 - accuracy: 0.7936 - val_loss: 0.5199 - val_accuracy: 0.7680
# Epoch 11/25
# 250/250 [==============================] - 38s 154ms/step - loss: 0.4329 - accuracy: 0.7995 - val_loss: 0.4846 - val_accuracy: 0.7810
# Epoch 12/25
# 250/250 [==============================] - 37s 150ms/step - loss: 0.4184 - accuracy: 0.8067 - val_loss: 0.4619 - val_accuracy: 0.7890
# Epoch 13/25
# 250/250 [==============================] - 36s 144ms/step - loss: 0.3986 - accuracy: 0.8188 - val_loss: 0.4887 - val_accuracy: 0.7825
# Epoch 14/25
# 250/250 [==============================] - 35s 139ms/step - loss: 0.3969 - accuracy: 0.8183 - val_loss: 0.4724 - val_accuracy: 0.8040
# Epoch 15/25
# 250/250 [==============================] - 35s 142ms/step - loss: 0.3819 - accuracy: 0.8256 - val_loss: 0.4699 - val_accuracy: 0.7975
# Epoch 16/25
# 250/250 [==============================] - 36s 143ms/step - loss: 0.3722 - accuracy: 0.8278 - val_loss: 0.4489 - val_accuracy: 0.7990
# Epoch 17/25
# 250/250 [==============================] - 36s 142ms/step - loss: 0.3660 - accuracy: 0.8316 - val_loss: 0.4584 - val_accuracy: 0.8035
# Epoch 18/25
# 250/250 [==============================] - 37s 147ms/step - loss: 0.3448 - accuracy: 0.8438 - val_loss: 0.4586 - val_accuracy: 0.8025
# Epoch 19/25
# 250/250 [==============================] - 35s 142ms/step - loss: 0.3373 - accuracy: 0.8514 - val_loss: 0.4774 - val_accuracy: 0.7920
# Epoch 20/25
# 250/250 [==============================] - 34s 136ms/step - loss: 0.3282 - accuracy: 0.8521 - val_loss: 0.4522 - val_accuracy: 0.7980
# Epoch 21/25
# 250/250 [==============================] - 35s 140ms/step - loss: 0.3096 - accuracy: 0.8649 - val_loss: 0.5122 - val_accuracy: 0.7820
# Epoch 22/25
# 250/250 [==============================] - 35s 139ms/step - loss: 0.2994 - accuracy: 0.8687 - val_loss: 0.5178 - val_accuracy: 0.7780
# Epoch 23/25
# 250/250 [==============================] - 35s 141ms/step - loss: 0.2905 - accuracy: 0.8751 - val_loss: 0.4915 - val_accuracy: 0.7975
# Epoch 24/25
# 250/250 [==============================] - 34s 137ms/step - loss: 0.2853 - accuracy: 0.8754 - val_loss: 0.5982 - val_accuracy: 0.7735
# Epoch 25/25
# 250/250 [==============================] - 34s 135ms/step - loss: 0.2819 - accuracy: 0.8781 - val_loss: 0.4971 - val_accuracy: 0.8045

# %% [markdown]
# ## Part 4 - Making a single prediction

# %%
import numpy as np
from keras.preprocessing import image
from keras.utils import load_img, img_to_array
test_image = load_img('dataset/single_prediction/cat_or_dog_1.jpg', target_size = (64, 64))
test_image = img_to_array(test_image)
test_image = np.expand_dims(test_image, axis = 0)
result = cnn.predict(test_image)
training_set.class_indices
if result[0][0] == 1:
  prediction = 'dog'
else:
  prediction = 'cat'
# Out:
# 1/1 [==============================] - 0s 21ms/step

# %%
print(prediction)
# Out:
# dog
